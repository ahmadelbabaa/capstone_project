# %%
import requests
import pandas as pd
import json
import numpy as np
import os
from datetime import datetime
import importlib

# SkillCorner Python Client
from skillcorner.client import SkillcornerClient

# Import credentials from credentials.py file
# Use importlib to reload in case credentials were updated
import credentials
importlib.reload(credentials)
from credentials import username, password

# Strip any whitespace that might cause issues
username = username.strip()
password = password.strip()

# Initialize the client
client = SkillcornerClient(username=username, password=password)

# %% [markdown]
# # 1.0 Get J1 League Matches for 2024 Season

# %%
# Get all available competitions
competitions = client.get_competitions()
competitions_df = pd.DataFrame(competitions)

print("Available competitions:")
print(competitions_df[['name', 'id']].to_string())

# Find J1 League (Japan)
j1_competitions = competitions_df[competitions_df['name'].str.contains('J1|Japan', case=False, na=False)]
print(f"\n\nJ1 League competitions found:")
print(j1_competitions[['name', 'id']])
# Out:
# Available competitions:
#                                                    name   id
# 0              AFC Olympic Qualification Women Playoffs  117
# 1                                     AFC U17 Asian Cup  493
# 2                                        AFF Suzuki Cup  115
# 3                               ASEAN Club Championship  445
# 4                                             Asian Cup   35
# 5                               Asian Cup Qualification  521
# 6                                      CAFA Nations Cup  602
# 7                                      Champions League  147
# 8                                  Champions League Two  448
# 9                        EAFF E-1 Football Championship  182
# 10                                  Gulf Cup of Nations  225
# 11                                       U-23 Asian Cup  588
# 12                                WC Qualification Asia  181
# 13                           West Asia Championship U23  373
# 14                             Women's Champions League  567
# 15                                           UAE LEAGUE  594
# 16                                       Copa Argentina  311
# 17                         Primera Division - 1st Phase   70
# 18                         Primera Division - 2nd Phase  376
# 19                                     Primera Nacional  412
# 20                                    Torneo Proyección  525
# 21                                                  Cup  533
# 22                                IDBank Premier League  532
# 23                                             A-League   61
# 24                                       A-League Women  410
# 25                                              2. Liga  103
# 26                                           Bundesliga   88
# 27                                           Frauenliga  605
# 28                                         Premyer Liqa  592
# 29                                        1B Pro League  119
# 30                                     Beker Van Belgie   91
# 31                Belgium First Division A, Playoffs 2A   58
# 32                                           Pro League   16
# 33                                         First League  332
# 34                                       Premier League  408
# 35                                                 LFPB  319
# 36                                     Brasileiro Women  467
# 37                                    Campeonato Baiano   69
# 38                                            Carioca 1  168
# 39                                        Catarinense 1  477
# 40                                   CBF Brasileiro U20  167
# 41                                       Copa do Brasil  308
# 42                                   Copa do Brasil U20  492
# 43                                             Gaúcho 1  341
# 44                                             Goiano 1  501
# 45                                            Mineiro 1  239
# 46                                         Paranaense 1  476
# 47                                          Paulista A2  474
# 48                                   Paulista, Serie A1   68
# 49                                         Paulista U20  490
# 50                                       Paulista Women  413
# 51                                  São Paulo Youth Cup  169
# 52                                              Série A   77
# 53                                              Série B   80
# 54                                              Série C  465
# 55                                              Série D   59
# 56                                  Supercopa do Brasil  335
# 57                                Africa Cup of Nations   37
# 58                  Africa Cup of Nations Qualification  193
# 59           African Nations Championship Qualification  197
# 60                           African Olympic Qualifiers  201
# 61                                 African Super League  317
# 62                          Africa Women Cup of Nations  213
# 63                                     Champions League  148
# 64                Champions League - Preliminary Rounds  330
# 65                                           COSAFA Cup  195
# 349                                          Pro League  151
# 350                                          Baltic Cup  378
# 351                                    Champions League   10
# 352                    Champions League - Qualification  534
# 353                            Europa Conference League  131
# 354            Europa Conference League - Qualification  535
# 355                                       Europa League    9
# 356                       Europa League - Qualification  536
# 357                               European Championship    2
# 358                    European Championship Qualifiers   34
# 359                            FIFA World Cup Qualifier   15
# 360                          Nation`s League - League A   21
# 361                          Nation`s League - League B  160
# 362                           Nations League - League C  443
# 363                          Nations League - Play-offs  491
# 364                                           Super Cup   13
# 365                      U17 Championship Qualification  144
# 366                           U17 European Championship  163
# 367                           U19 European Championship  164
# 368                U19 European Championship Qualifiers  200
# 369                                    U20 Elite League  218
# 370                           U21 European Championship   49
# 371                U21 European Championship Qualifiers   62
# 372       Women's Championship Qualification - League A  461
# 373       Women's Championship Qualification - Play-off  463
# 374                            Women`s Champions League  141
# 375                                  Women's Europa Cup  577
# 376                       Women`s European Championship  166
# 377                   Women's Nations League - League A  331
# 378                   Women's Nations League - League B  485
# 379                     Women's WC Qualification Europe  217
# 380                              Women U17 Championship  176
# 381                              Women U19 Championship  177
# 382                                        Youth League   78
# 383                                      Premier League   26
# 384                                          U19 League  453
# 385                                    Primera Division   95
# 386                                    Segunda División  547
# 387                                 Major League Soccer   60
# 388                                        MLS Next Pro  190
# 389                                    NCAA D1 Big East  478
# 390                                     NCAA D1 Big Ten  479
# 391                                                NWSL  126
# 392                                  NWSL Challenge Cup  154
# 393                                    USL Championship  191
# 394                                        USL League 1  454
# 395                             USL Super League, Women  489
# 396                                        Super League  591
# 397                                    Primera División  469
# 398                                          V.League 1  475
# 399                                           Superliga  593
# 400                           FIFA Intercontinental Cup  575
#
#
# J1 League competitions found:
#                           name   id
# 252  J1 100 Year Vision League  600
# 253                  J1 League   87
# 257         Japanese Super Cup  599

# %% [markdown]
# # Set the J1 League competition ID (update this based on the output above)
# # You may need to manually set this after seeing the available competitions
# j1_competition_id = j1_competitions.iloc[0]['id'] if len(j1_competitions) > 0 else None
#
# if j1_competition_id:
#     print(f"Using competition ID: {j1_competition_id}")
# else:
#     print("Please manually set j1_competition_id based on the competitions list above")

# %%
# Get all matches for J1 League 2024 season
params = {
    'competition': 87,
}

matches = client.get_matches(params=params)
matches_df = pd.DataFrame(matches)

print(f"Found {len(matches_df)} matches for J1 League 2024 season")
print("\nSample matches:")
print(matches_df[['id', 'date_time', 'home_team', 'away_team']].head(10))
# Out:
# Found 380 matches for J1 League 2024 season
#
# Sample matches:
#         id             date_time  \
# 0  1900931  2024-12-08T05:00:00Z
# 1  1901679  2024-12-08T05:00:00Z
# 2  1901680  2024-12-08T05:00:00Z
# 3  1901681  2024-12-08T05:00:00Z
# 4  1901682  2024-12-08T05:00:00Z
# 5  1901683  2024-12-08T05:00:00Z
# 6  1901684  2024-12-08T05:00:00Z
# 7  1901685  2024-12-08T05:00:00Z
# 8  1901686  2024-12-08T05:00:00Z
# 9  1901687  2024-12-08T05:00:00Z
#
#                                        home_team  \
# 0          {'id': 1473, 'short_name': 'Sapporo'}
# 1  {'id': 1460, 'short_name': 'Kashima Antlers'}
# 2       {'id': 1459, 'short_name': 'Urawa Reds'}
# 3            {'id': 1465, 'short_name': 'Tokyo'}
# 4         {'id': 1469, 'short_name': 'Kawasaki'}
# 5          {'id': 1458, 'short_name': 'Marinos'}
# 6      {'id': 2660, 'short_name': 'Kyoto Sanga'}
# 7      {'id': 1463, 'short_name': 'Gamba Osaka'}
# 8       {'id': 929, 'short_name': 'Vissel Kobe'}
# 9       {'id': 1470, 'short_name': 'Sagan Tosu'}
#
#                                        away_team
# 0   {'id': 1466, 'short_name': 'Kashiwa Reysol'}
# 1   {'id': 3380, 'short_name': 'Machida Zelvia'}
# 2  {'id': 2926, 'short_name': 'Albirex Niigata'}
# 3     {'id': 1468, 'short_name': 'Cerezo Osaka'}
# 4   {'id': 2659, 'short_name': 'Avispa Fukuoka'}
# 5   {'id': 1461, 'short_name': 'Nagoya Grampus'}
# 6      {'id': 3384, 'short_name': 'Tokyo Verdy'}
# 7        {'id': 1467, 'short_name': 'Hiroshima'}
# 8  {'id': 1472, 'short_name': 'Shonan Bellmare'}
# 9      {'id': 931, 'short_name': 'Jubilo Iwata'}

# %%
match_dates = pd.to_datetime(matches_df["date_time"], errors="coerce")
print(f"Min date: {match_dates.min()}")
print(f"Max date: {match_dates.max()}")
# Out:
# Min date: 2024-02-23 05:00:00+00:00
# Max date: 2024-12-08 05:00:00+00:00

# %%
# 2.0 Extract Tracking Data for All Matches

# %%
# Create output directory
output_dir = 'data/tracking_j1_2024'
os.makedirs(output_dir, exist_ok=True)

print(f"Will save tracking data to: {output_dir}")
print(f"Total matches to process: {len(matches_df)}")
# Out:
# Will save tracking data to: data/tracking_j1_2024
# Total matches to process: 380

# %%
# Extract tracking data for all matches
results = []

for idx, match in matches_df.iterrows():
    match_id = match['id']
    home_team = match.get('home_team', {}).get('name', 'Unknown') if isinstance(match.get('home_team'), dict) else 'Unknown'
    away_team = match.get('away_team', {}).get('name', 'Unknown') if isinstance(match.get('away_team'), dict) else 'Unknown'
    
    # Check if file already exists
    filepath = os.path.join(output_dir, f"{match_id}_tracking_extrapolated.jsonl")
    
    if os.path.exists(filepath):
        print(f"\n[{idx+1}/{len(matches_df)}] Match ID: {match_id} - Already exists, skipping")
        results.append({
            'match_id': match_id,
            'home_team': home_team,
            'away_team': away_team,
            'date': match.get('date_time'),
            'status': 'success',
            'filepath': filepath
        })
        continue
    
    print(f"\n[{idx+1}/{len(matches_df)}] Processing Match ID: {match_id}")
    print(f"   {home_team} vs {away_team}")
    
    try:
        # Save tracking data using SkillCorner client
        # The data_version=3 parameter gets the extrapolated tracking data
        client.save_match_tracking_data(
            match_id,
            params={'data_version': 3},
            filepath=filepath
        )
        
        print(f"   ✓ Saved to {filepath}")
        
        results.append({
            'match_id': match_id,
            'home_team': home_team,
            'away_team': away_team,
            'date': match.get('date_time'),
            'status': 'success',
            'filepath': filepath
        })
        
    except Exception as e:
        print(f"   ✗ Error: {str(e)}")
        results.append({
            'match_id': match_id,
            'home_team': home_team,
            'away_team': away_team,
            'date': match.get('date_time'),
            'status': 'failed',
            'error': str(e)
        })

# Create results summary
results_df = pd.DataFrame(results)

print("\n" + "="*70)
print("EXTRACTION COMPLETE")
print("="*70)
print(f"Total matches: {len(results_df)}")
print(f"Successful: {len(results_df[results_df['status'] == 'success'])}")
print(f"Failed: {len(results_df[results_df['status'] == 'failed'])}")
# Out:
# [1/380] Match ID: 1900931 - Already exists, skipping
#
# [2/380] Match ID: 1901679 - Already exists, skipping
#
# [3/380] Match ID: 1901680 - Already exists, skipping
#
# [4/380] Match ID: 1901681 - Already exists, skipping
#
# [5/380] Match ID: 1901682 - Already exists, skipping
#
# [6/380] Match ID: 1901683 - Already exists, skipping
#
# [7/380] Match ID: 1901684 - Already exists, skipping
#
# [8/380] Match ID: 1901685 - Already exists, skipping
#
# [9/380] Match ID: 1901686 - Already exists, skipping
#
# [10/380] Match ID: 1901687 - Already exists, skipping
#
# [11/380] Match ID: 1888503 - Already exists, skipping
#
# [12/380] Match ID: 1886285 - Already exists, skipping
#
# [13/380] Match ID: 1886286 - Already exists, skipping
#
# [14/380] Match ID: 1886287 - Already exists, skipping
#
# [15/380] Match ID: 1886288 - Already exists, skipping
#
# [16/380] Match ID: 1886289 - Already exists, skipping
#
# [17/380] Match ID: 1886290 - Already exists, skipping
#
# [18/380] Match ID: 1886291 - Already exists, skipping
#
# [19/380] Match ID: 1886292 - Already exists, skipping
#
# [20/380] Match ID: 1886293 - Already exists, skipping
#
# [21/380] Match ID: 1873807 - Already exists, skipping
#
# [22/380] Match ID: 1862666 - Already exists, skipping
#
# [23/380] Match ID: 1860583 - Already exists, skipping
#
# [24/380] Match ID: 1852459 - Already exists, skipping
#
# [25/380] Match ID: 1852460 - Already exists, skipping
#
# [26/380] Match ID: 1852450 - Already exists, skipping
#
# [27/380] Match ID: 1852451 - Already exists, skipping
#
# [28/380] Match ID: 1852452 - Already exists, skipping
#
# [29/380] Match ID: 1852453 - Already exists, skipping
#
# [30/380] Match ID: 1852454 - Already exists, skipping
#
# [31/380] Match ID: 1852455 - Already exists, skipping
#
# [32/380] Match ID: 1852456 - Already exists, skipping
#
# [33/380] Match ID: 1852457 - Already exists, skipping
#
# [34/380] Match ID: 1834425 - Already exists, skipping
#
# [35/380] Match ID: 1834426 - Already exists, skipping
#
# [36/380] Match ID: 1834427 - Already exists, skipping
#
# [37/380] Match ID: 1834428 - Already exists, skipping
#
# [38/380] Match ID: 1834429 - Already exists, skipping
#
# [39/380] Match ID: 1830834 - Already exists, skipping
#
# [40/380] Match ID: 1830835 - Already exists, skipping
#
# [41/380] Match ID: 1828346 - Already exists, skipping
#
# [42/380] Match ID: 1810119 - Already exists, skipping
#
# [43/380] Match ID: 1810956 - Already exists, skipping
#
# [44/380] Match ID: 1810957 - Already exists, skipping
#
# [45/380] Match ID: 1798964 - Already exists, skipping
#
# [46/380] Match ID: 1798965 - Already exists, skipping
#
# [319/380] Match ID: 1481593 - Already exists, skipping
#
# [320/380] Match ID: 1481594 - Already exists, skipping
#
# [321/380] Match ID: 1481595 - Already exists, skipping
#
# [322/380] Match ID: 1468639 - Already exists, skipping
#
# [323/380] Match ID: 1468640 - Already exists, skipping
#
# [324/380] Match ID: 1468641 - Already exists, skipping
#
# [325/380] Match ID: 1468642 - Already exists, skipping
#
# [326/380] Match ID: 1468643 - Already exists, skipping
#
# [327/380] Match ID: 1468644 - Already exists, skipping
#
# [328/380] Match ID: 1468645 - Already exists, skipping
#
# [329/380] Match ID: 1468646 - Already exists, skipping
#
# [330/380] Match ID: 1468647 - Already exists, skipping
#
# [331/380] Match ID: 1468648 - Already exists, skipping
#
# [332/380] Match ID: 1462093 - Already exists, skipping
#
# [333/380] Match ID: 1462094 - Already exists, skipping
#
# [334/380] Match ID: 1461403 - Already exists, skipping
#
# [335/380] Match ID: 1461404 - Already exists, skipping
#
# [336/380] Match ID: 1461405 - Already exists, skipping
#
# [337/380] Match ID: 1461406 - Already exists, skipping
#
# [338/380] Match ID: 1461407 - Already exists, skipping
#
# [339/380] Match ID: 1461408 - Already exists, skipping
#
# [340/380] Match ID: 1461409 - Already exists, skipping
#
# [341/380] Match ID: 1460307 - Already exists, skipping
#
# [342/380] Match ID: 1444278 - Already exists, skipping
#
# [343/380] Match ID: 1444279 - Already exists, skipping
#
# [344/380] Match ID: 1444280 - Already exists, skipping
#
# [345/380] Match ID: 1442985 - Already exists, skipping
#
# [346/380] Match ID: 1442986 - Already exists, skipping
#
# [347/380] Match ID: 1442987 - Already exists, skipping
#
# [348/380] Match ID: 1442988 - Already exists, skipping
#
# [349/380] Match ID: 1442338 - Already exists, skipping
#
# [350/380] Match ID: 1442339 - Already exists, skipping
#
# [351/380] Match ID: 1442340 - Already exists, skipping
#
# [352/380] Match ID: 1434052 - Already exists, skipping
#
# [353/380] Match ID: 1432244 - Already exists, skipping
#
# [354/380] Match ID: 1432246 - Already exists, skipping
#
# [355/380] Match ID: 1432856 - Already exists, skipping
#
# [356/380] Match ID: 1432247 - Already exists, skipping
#
# [357/380] Match ID: 1432248 - Already exists, skipping
#
# [358/380] Match ID: 1432249 - Already exists, skipping
#
# [359/380] Match ID: 1432250 - Already exists, skipping
#
# [360/380] Match ID: 1432251 - Already exists, skipping
#
# [361/380] Match ID: 1423887 - Already exists, skipping
#
# [362/380] Processing Match ID: 1422006
#    Unknown vs Unknown
#    ✓ Saved to data/tracking_j1_2024\1422006_tracking_extrapolated.jsonl
#
# [363/380] Processing Match ID: 1422007
#    Unknown vs Unknown
#    ✓ Saved to data/tracking_j1_2024\1422007_tracking_extrapolated.jsonl
#
# [364/380] Processing Match ID: 1422636
#    Unknown vs Unknown
#    ✓ Saved to data/tracking_j1_2024\1422636_tracking_extrapolated.jsonl
#
# [365/380] Processing Match ID: 1422009
#    Unknown vs Unknown
#    ✓ Saved to data/tracking_j1_2024\1422009_tracking_extrapolated.jsonl
#
# [366/380] Processing Match ID: 1422010
#    Unknown vs Unknown
#    ✓ Saved to data/tracking_j1_2024\1422010_tracking_extrapolated.jsonl
#
# [367/380] Processing Match ID: 1422011
#    Unknown vs Unknown
#    ✓ Saved to data/tracking_j1_2024\1422011_tracking_extrapolated.jsonl
#
# [368/380] Processing Match ID: 1422012
#    Unknown vs Unknown
#    ✓ Saved to data/tracking_j1_2024\1422012_tracking_extrapolated.jsonl
#
# [369/380] Processing Match ID: 1421015
#    Unknown vs Unknown
#    ✓ Saved to data/tracking_j1_2024\1421015_tracking_extrapolated.jsonl
#
# [370/380] Processing Match ID: 1421016
#    Unknown vs Unknown
#    ✓ Saved to data/tracking_j1_2024\1421016_tracking_extrapolated.jsonl
#
# [371/380] Match ID: 1413533 - Already exists, skipping
#
# [372/380] Match ID: 1413534 - Already exists, skipping
#
# [373/380] Match ID: 1411836 - Already exists, skipping
#
# [374/380] Match ID: 1412335 - Already exists, skipping
#
# [375/380] Match ID: 1412336 - Already exists, skipping
#
# [376/380] Match ID: 1411839 - Already exists, skipping
#
# [377/380] Match ID: 1412337 - Already exists, skipping
#
# [378/380] Match ID: 1411840 - Already exists, skipping
#
# [379/380] Match ID: 1410827 - Already exists, skipping
#
# [380/380] Match ID: 1410828 - Already exists, skipping
#
# ======================================================================
# EXTRACTION COMPLETE
# ======================================================================
# Total matches: 380
# Successful: 380
# Failed: 0

# %%
# Save extraction summary
summary_file = 'data/j1_2024_extraction_summary.csv'
results_df.to_csv(summary_file, index=False)
print(f"\n✓ Extraction summary saved to {summary_file}")

# Display results
results_df
# Out:
# ✓ Extraction summary saved to data/j1_2024_extraction_summary.csv
#      match_id home_team away_team                  date   status  \
# 0     1900931   Unknown   Unknown  2024-12-08T05:00:00Z  success
# 1     1901679   Unknown   Unknown  2024-12-08T05:00:00Z  success
# 2     1901680   Unknown   Unknown  2024-12-08T05:00:00Z  success
# 3     1901681   Unknown   Unknown  2024-12-08T05:00:00Z  success
# 4     1901682   Unknown   Unknown  2024-12-08T05:00:00Z  success
# ..        ...       ...       ...                   ...      ...
# 375   1411839   Unknown   Unknown  2024-02-24T05:00:00Z  success
# 376   1412337   Unknown   Unknown  2024-02-24T05:00:00Z  success
# 377   1411840   Unknown   Unknown  2024-02-24T04:00:00Z  success
# 378   1410827   Unknown   Unknown  2024-02-23T09:00:00Z  success
# 379   1410828   Unknown   Unknown  2024-02-23T05:00:00Z  success
#
#                                               filepath
# 0    data/tracking_j1_2024\1900931_tracking_extrapo...
# 1    data/tracking_j1_2024\1901679_tracking_extrapo...
# 2    data/tracking_j1_2024\1901680_tracking_extrapo...
# 3    data/tracking_j1_2024\1901681_tracking_extrapo...
# 4    data/tracking_j1_2024\1901682_tracking_extrapo...
# ..                                                 ...
# 375  data/tracking_j1_2024\1411839_tracking_extrapo...
# 376  data/tracking_j1_2024\1412337_tracking_extrapo...
# 377  data/tracking_j1_2024\1411840_tracking_extrapo...
# 378  data/tracking_j1_2024\1410827_tracking_extrapo...
# 379  data/tracking_j1_2024\1410828_tracking_extrapo...
#
# [380 rows x 6 columns]

# %%
# Display failed matches and their errors
failed_matches = results_df[results_df['status'] == 'failed']

if len(failed_matches) > 0:
    print(f"Failed matches ({len(failed_matches)}):")
    print("\n")
    for idx, row in failed_matches.iterrows():
        print(f"Match ID: {row['match_id']}")
        print(f"  {row['home_team']} vs {row['away_team']}")
        print(f"  Date: {row['date']}")
        print(f"  Error: {row.get('error', 'No error message')}")
        print("-" * 70)
else:
    print("No failed matches found!")
# Out:
# No failed matches found!

# %%
# Group failed matches by error type
failed_matches = results_df[results_df['status'] == 'failed']

if len(failed_matches) > 0:
    # Show unique error types
    error_types = failed_matches.groupby('error').size()
    print(f"Error types and counts:")
    for error, count in error_types.items():
        print(f"\n{count} matches failed with:")
        print(f"  {error}")
        
    print("\n" + "="*70)
    print(f"\nFirst few failed matches:")
    failed_matches[['match_id', 'home_team', 'away_team', 'date', 'error']].head(10)
else:
    print("No failed matches!")
# Out:
# No failed matches!

# %% [markdown]
# # 3.0 Extract Match Metadata for All Matches

# %%
# Extract match metadata (player info, team info, etc.)
metadata_dir = 'data/metadata_j1_2024'
os.makedirs(metadata_dir, exist_ok=True)

metadata_results = []

for idx, match in matches_df.iterrows():
    match_id = match['id']
    
    print(f"[{idx+1}/{len(matches_df)}] Getting metadata for Match ID: {match_id}")
    
    try:
        # Get match metadata
        match_metadata = client.get_match(match_id)
        
        # Save metadata to JSON file
        filepath = os.path.join(metadata_dir, f"{match_id}_metadata.json")
        with open(filepath, 'w') as f:
            json.dump(match_metadata, f, indent=2)
        
        print(f"   ✓ Saved metadata to {filepath}")
        
        metadata_results.append({
            'match_id': match_id,
            'status': 'success',
            'filepath': filepath
        })
        
    except Exception as e:
        print(f"   ✗ Error: {str(e)}")
        metadata_results.append({
            'match_id': match_id,
            'status': 'failed',
            'error': str(e)
        })

print(f"\n✓ Metadata extraction complete")
print(f"Successful: {len([r for r in metadata_results if r['status'] == 'success'])}")
print(f"Failed: {len([r for r in metadata_results if r['status'] == 'failed'])}")
# Out:
# [1/380] Getting metadata for Match ID: 1900931
#    ✓ Saved metadata to data/metadata_j1_2024\1900931_metadata.json
# [2/380] Getting metadata for Match ID: 1901679
#    ✓ Saved metadata to data/metadata_j1_2024\1901679_metadata.json
# [3/380] Getting metadata for Match ID: 1901680
#    ✓ Saved metadata to data/metadata_j1_2024\1901680_metadata.json
# [4/380] Getting metadata for Match ID: 1901681
#    ✓ Saved metadata to data/metadata_j1_2024\1901681_metadata.json
# [5/380] Getting metadata for Match ID: 1901682
#    ✓ Saved metadata to data/metadata_j1_2024\1901682_metadata.json
# [6/380] Getting metadata for Match ID: 1901683
#    ✓ Saved metadata to data/metadata_j1_2024\1901683_metadata.json
# [7/380] Getting metadata for Match ID: 1901684
#    ✓ Saved metadata to data/metadata_j1_2024\1901684_metadata.json
# [8/380] Getting metadata for Match ID: 1901685
#    ✓ Saved metadata to data/metadata_j1_2024\1901685_metadata.json
# [9/380] Getting metadata for Match ID: 1901686
# [377/380] Getting metadata for Match ID: 1412337
#    ✓ Saved metadata to data/metadata_j1_2024\1412337_metadata.json
# [378/380] Getting metadata for Match ID: 1411840
#    ✓ Saved metadata to data/metadata_j1_2024\1411840_metadata.json
# [379/380] Getting metadata for Match ID: 1410827
#    ✓ Saved metadata to data/metadata_j1_2024\1410827_metadata.json
# [380/380] Getting metadata for Match ID: 1410828
#    ✓ Saved metadata to data/metadata_j1_2024\1410828_metadata.json
#
# ✓ Metadata extraction complete
# Successful: 380
# Failed: 0

# %% [markdown]
# # 4.0 Load and Process Sample Tracking Data

# %%
# Load a sample tracking file (following the tutorial pattern)
import glob

# Get all tracking files directly from directory
all_tracking_files = glob.glob('data/tracking_j1_2024/*.jsonl')

# Find a valid non-empty file
sample_file = None
match_id = None

for file in all_tracking_files:
    # Check if file is not empty
    if os.path.getsize(file) > 0:
        sample_file = file
        # Extract match_id from filename
        match_id = int(os.path.basename(file).split('_')[0])
        break

if sample_file:
    print(f"Loading sample tracking data from:")
    print(f"  Match ID: {match_id}")
    print(f"  File: {sample_file}")
    print(f"  File size: {os.path.getsize(sample_file) / (1024**2):.1f} MB")
    
    try:
        # The file is formatted as a JSON array, not JSONL
        # Load as regular JSON array
        with open(sample_file, 'r') as f:
            raw_data = json.load(f)
        
        raw_data = pd.DataFrame(raw_data)
        
        print(f"✓ Loaded {len(raw_data)} raw frames")
        
        # Process tracking data (following tutorial)
        tracking_df = pd.json_normalize(
            raw_data.to_dict('records'), 
            'player_data',
            ['frame', 'timestamp', 'period', 'possession', 'ball_data']
        )
        
        # Extract possession info
        tracking_df['possession_player_id'] = tracking_df['possession'].apply(lambda x: x.get('player_id') if isinstance(x, dict) else None)
        tracking_df['possession_group'] = tracking_df['possession'].apply(lambda x: x.get('group') if isinstance(x, dict) else None)
        
        # Expand ball_data
        tracking_df[['ball_x', 'ball_y', 'ball_z', 'is_detected_ball']] = pd.json_normalize(tracking_df.ball_data)
        
        # Clean up
        tracking_df = tracking_df.drop(columns=['possession', 'ball_data'])
        tracking_df['match_id'] = match_id
        
        print(f"✓ Processed {len(tracking_df)} tracking frames")
        print(f"\nSample data:")
        display(tracking_df.head())
        
    except Exception as e:
        print(f"✗ Error loading file: {str(e)}")
        import traceback
        traceback.print_exc()
else:
    print("No valid tracking data files found")
# Out:
# Loading sample tracking data from:
#   Match ID: 1410827
#   File: data/tracking_j1_2024\1410827_tracking_extrapolated.jsonl
#   File size: 135.4 MB
# ✓ Loaded 57322 raw frames
# ✓ Processed 968836 tracking frames
#
# Sample data:
#        x      y  player_id  is_detected frame    timestamp period  \
# 0 -40.80  -0.33       7698        False    10  00:00:00.00    1.0
# 1 -17.47  -2.01     255000         True    10  00:00:00.00    1.0
# 2 -17.20 -13.71      26960        False    10  00:00:00.00    1.0
# 3 -17.43   5.48     727006         True    10  00:00:00.00    1.0
# 4 -18.00 -25.17     731816        False    10  00:00:00.00    1.0
#
#    possession_player_id possession_group  ball_x  ball_y  ball_z  \
# 0                   NaN             None    -0.6   -0.48    0.24
# 1                   NaN             None    -0.6   -0.48    0.24
# 2                   NaN             None    -0.6   -0.48    0.24
# 3                   NaN             None    -0.6   -0.48    0.24
# 4                   NaN             None    -0.6   -0.48    0.24
#
#    is_detected_ball  match_id
# 0              True   1410827
# 1              True   1410827
# 2              True   1410827
# 3              True   1410827
# 4              True   1410827

# %% [markdown]
# # 5.0 Process Match Metadata (Player Info)

# %%
# Load corresponding metadata file
metadata_file = os.path.join(metadata_dir, f"{match_id}_metadata.json")

if os.path.exists(metadata_file):
    with open(metadata_file, 'r') as f:
        match_metadata = json.load(f)
    
    # Process metadata (following tutorial pattern)
    raw_match_df = pd.json_normalize(match_metadata, max_level=2)
    raw_match_df['home_team_side'] = raw_match_df['home_team_side'].astype(str)
    
    # Extract player information
    players_df = pd.json_normalize(
        raw_match_df.to_dict('records'),
        record_path='players',
        meta=['home_team_score', 'away_team_score', 'date_time',
              'home_team_side',
              'home_team.name', 'home_team.id',
              'away_team.name', 'away_team.id']
    )
    
    # Helper function for time conversion
    def time_to_seconds(time_str):
        if time_str is None:
            return 90 * 60
        h, m, s = map(int, time_str.split(':'))
        return h * 3600 + m * 60 + s
    
    # Process players who actually played
    players_df = players_df[~((players_df.start_time.isna()) & (players_df.end_time.isna()))]
    players_df['total_time'] = players_df['end_time'].apply(time_to_seconds) - players_df['start_time'].apply(time_to_seconds)
    
    # Add flags
    players_df['is_gk'] = players_df['player_role.acronym'] == 'GK'
    players_df['home_away_player'] = np.where(players_df.team_id == players_df['home_team.id'], 'Home', 'Away')
    players_df['team_name'] = np.where(players_df.team_id == players_df['home_team.id'], 
                                        players_df['home_team.name'], 
                                        players_df['away_team.name'])
    
    print(f"✓ Loaded metadata for {len(players_df)} players")
    print(f"\nPlayers overview:")
    display(players_df[['short_name', 'number', 'team_name', 'player_role.name', 'total_time']].head(10))
else:
    print(f"Metadata file not found: {metadata_file}")
# Out:
# ✓ Loaded metadata for 32 players
#
# Players overview:
#    short_name  number        team_name          player_role.name  total_time
# 0    T. Fujii      15  Kashima Antlers              Right Winger        2627
# 1     S. Nago      30  Kashima Antlers        Attacking Midfield         128
# 2  Y. Higuchi      14  Kashima Antlers              Right Winger        5400
# 3     K. Sano      25  Kashima Antlers   Left Defensive Midfield        5400
# 4   K. Chinen      13  Kashima Antlers  Right Defensive Midfield        5272
# 5      S. Doi       8  Kashima Antlers        Attacking Midfield        2773
# 6   K. Junker      77   Nagoya Grampus            Center Forward        5400
# 7  S. Inagaki      15   Nagoya Grampus        Defensive Midfield        5400
# 8   Y. Nogami       2   Nagoya Grampus         Right Center Back        5400
# 9     N. Ueda      55  Kashima Antlers         Right Center Back        5400

# %% [markdown]
# # All J1 League 2024 tracking data has been extracted!
#
# The data is now saved in:
# - **Tracking data**: `data/tracking_j1_2024/` (one .jsonl file per match)
# - **Metadata**: `data/metadata_j1_2024/` (one .json file per match)
# - **Summary**: `data/j1_2024_extraction_summary.csv`
#
# You can now process each match's tracking data following the patterns shown in the SkillCorner tutorial.
